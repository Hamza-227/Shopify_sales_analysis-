# %%
import pandas as pd

# %%
df = pd.read_csv('shopify_cleaned.csv')

# %%
# Putting data into MySQL database using SQLAlchemy and PyMySQL
from sqlalchemy import create_engine
import pandas as pd

username = "root"
password = "YOUR_PASSWORD_HERE"
host = "localhost"
port = 3306
database = "shopify_sales_analysis"

engine = create_engine(
    f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"
)

df.to_sql("shopify_data", engine, if_exists="replace", index=False)
